# %%
# !pip install labelme tensorflow opencv-python matplotlib albumentations
# Out:
# Requirement already satisfied: labelme in /opt/conda/lib/python3.11/site-packages (6.0.0)
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.11/site-packages (2.21.0)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.11/site-packages (4.13.0.92)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.9.2)
# Requirement already satisfied: albumentations in /opt/conda/lib/python3.11/site-packages (2.0.8)
# Requirement already satisfied: imgviz>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from labelme) (2.0.0)
# Requirement already satisfied: loguru in /opt/conda/lib/python3.11/site-packages (from labelme) (0.7.3)
# Requirement already satisfied: natsort>=7.1.0 in /opt/conda/lib/python3.11/site-packages (from labelme) (8.4.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from labelme) (2.0.1)
# Requirement already satisfied: osam>=0.3.1 in /opt/conda/lib/python3.11/site-packages (from labelme) (0.3.1)
# Requirement already satisfied: pillow>=2.8 in /opt/conda/lib/python3.11/site-packages (from labelme) (10.4.0)
# Requirement already satisfied: pyqt5-qt5!=5.15.13 in /opt/conda/lib/python3.11/site-packages (from labelme) (5.15.18)
# Requirement already satisfied: pyqt5>=5.14.0 in /opt/conda/lib/python3.11/site-packages (from labelme) (5.15.11)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from labelme) (6.0.2)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.11/site-packages (from labelme) (0.24.0)
# Requirement already satisfied: tifffile in /opt/conda/lib/python3.11/site-packages (from labelme) (2024.8.24)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from tensorflow) (72.2.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: scipy>=1.10.0 in /opt/conda/lib/python3.11/site-packages (from albumentations) (1.14.1)
# Requirement already satisfied: pydantic>=2.9.2 in /opt/conda/lib/python3.11/site-packages (from albumentations) (2.13.0)
# Requirement already satisfied: albucore==0.0.24 in /opt/conda/lib/python3.11/site-packages (from albumentations) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /opt/conda/lib/python3.11/site-packages (from albumentations) (4.13.0.92)
# Requirement already satisfied: stringzilla>=3.10.4 in /opt/conda/lib/python3.11/site-packages (from albucore==0.0.24->albumentations) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /opt/conda/lib/python3.11/site-packages (from albucore==0.0.24->albumentations) (6.5.16)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: cmap>=0.1.0 in /opt/conda/lib/python3.11/site-packages (from imgviz>=2.0.0->labelme) (0.7.2)
# Requirement already satisfied: rich in /opt/conda/lib/python3.11/site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in /opt/conda/lib/python3.11/site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /opt/conda/lib/python3.11/site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from osam>=0.3.1->labelme) (8.1.7)
# Requirement already satisfied: gdown>=5.2.1 in /opt/conda/lib/python3.11/site-packages (from osam>=0.3.1->labelme) (6.0.0)
# Requirement already satisfied: onnxruntime>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from osam>=0.3.1->labelme) (1.24.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.9.2->albumentations) (2.46.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.9.2->albumentations) (0.4.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.15 in /opt/conda/lib/python3.11/site-packages (from pyqt5>=5.14.0->labelme) (12.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.11/site-packages (from scikit-image->labelme) (3.3)
# Requirement already satisfied: imageio>=2.33 in /opt/conda/lib/python3.11/site-packages (from scikit-image->labelme) (2.35.1)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/conda/lib/python3.11/site-packages (from scikit-image->labelme) (0.4)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.11/site-packages (from gdown>=5.2.1->osam>=0.3.1->labelme) (4.12.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from gdown>=5.2.1->osam>=0.3.1->labelme) (3.25.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from gdown>=5.2.1->osam>=0.3.1->labelme) (4.66.5)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from onnxruntime>=1.23.2->osam>=0.3.1->labelme) (1.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras>=3.12.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras>=3.12.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4->gdown>=5.2.1->osam>=0.3.1->labelme) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.11/site-packages (from requests[socks]->gdown>=5.2.1->osam>=0.3.1->labelme) (1.7.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy->onnxruntime>=1.23.2->osam>=0.3.1->labelme) (1.3.0)

# %%
import os
import time #gives us time to move around
import uuid #gives each picture a unique identifier
import cv2 #allows us to work with sensors and cameras

# %%
IMAGES_PATH = os.path.join('data','images') #images going to go in folder called data
number_images = 30 #collect 30 images for samples

# %%
cap = cv2.VideoCapture(0) #connecting to video capture device
#running loop to capture images
for imgnum in range(number_images):
    print('Collecting Image{}'.format(imgnum))
    #read from our capture device
    ret, frame = cap.read()
    #naming images
    imgname = os.path.join(IMAGES_PATH,f'{str(uuid.uuid1())}.jpg')
    cv2.imwrite(imgname,frame)
    cv2.imshow('frame',frame)
    #0.5 sec in between every picture
    time.sleep(0.5)

    #loop end case
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting Image0
# [ WARN:0@635.176] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video1): can't open camera by index
# [ WARN:0@635.177] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 1
# > must be less than
# >     'device_list->nb_devices' is 0
#
#
# [ERROR:0@635.177] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[5], line 9
#       7 #naming images
#       8 imgname = os.path.join(IMAGES_PATH,f'{str(uuid.uuid1())}.jpg')
# ----> 9 cv2.imwrite(imgname,frame)
#      10 cv2.imshow('frame',frame)
#      11 #0.5 sec in between every picture
#
# error: OpenCV(4.13.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:1193: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'
